# %% [markdown]
# <a href="https://colab.research.google.com/github/KyeoRaeHan/AI_Solution_Course_DL/blob/main/MLP%EC%8B%A4%EC%8A%B5_3%EA%B0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd /content/drive/MyDrive/Tacademy-딥러닝
# Out:
# /content/drive/MyDrive/Tacademy-딥러닝

# %%
import pandas as pd

# %%
dataset = pd.read_csv("./data/diabetes.csv")
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# 0. 사용할 패키지 불러오기
import numpy as np
from keras.models import Sequential
from keras.layers import Dense

# 랜덤시드 고정시키기
np.random.seed(5)

# 1. 데이터 준비하기
# dataset = np.loadtxt("./data/diabetes.csv", delimiter=",")

# 2. 데이터셋 생성하기
x_train = dataset.iloc[:600, 0:8]
y_train = dataset.iloc[:600,8]
x_val = dataset.iloc[600:700, 0:8]
y_val = dataset.iloc[600:700, 8]
x_test = dataset.iloc[700:,0:8]
y_test = dataset.iloc[700:,8]

# 3. 모델 구성하기
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# 4. 모델 학습과정 설정하기
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# 5. 모델 학습시키기
model.fit(x_train, y_train, epochs=150, batch_size=64, validation_data=(x_val, y_val))

# 6. 모델 평가하기
scores = model.evaluate(x_test, y_test)
print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))
# Out:
# Epoch 1/150
# 10/10 [==============================] - 1s 27ms/step - loss: 11.2980 - accuracy: 0.3653 - val_loss: 8.6643 - val_accuracy: 0.3300
# Epoch 2/150
# 10/10 [==============================] - 0s 4ms/step - loss: 6.8389 - accuracy: 0.3658 - val_loss: 4.1555 - val_accuracy: 0.3200
# Epoch 3/150
# 10/10 [==============================] - 0s 4ms/step - loss: 3.0321 - accuracy: 0.3680 - val_loss: 1.3962 - val_accuracy: 0.4100
# Epoch 4/150
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5594 - accuracy: 0.5068 - val_loss: 1.4821 - val_accuracy: 0.6900
# Epoch 5/150
# 10/10 [==============================] - 0s 4ms/step - loss: 1.6402 - accuracy: 0.6302 - val_loss: 1.0980 - val_accuracy: 0.5500
# Epoch 6/150
# 10/10 [==============================] - 0s 6ms/step - loss: 1.1566 - accuracy: 0.5741 - val_loss: 1.0762 - val_accuracy: 0.5000
# Epoch 7/150
# ...
